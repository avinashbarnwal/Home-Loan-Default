# %%
import pandas as pd
import numpy as np
import gc

buro_bal = pd.read_pickle("buro_bal.p")
bureau   = pd.read_pickle("bureau.p")

# %%
ID = bureau['SK_ID_CURR'].unique()
data_base = pd.DataFrame()
data_base['SK_ID_CURR'] = ID

def trade_count(filter_type1=None,filter_type2 = None,data=None,original_data=None,new_varname = None):
    if (filter_type1 is not None) and (filter_type2 is not None):
        temp_series = original_data[(original_data["CREDIT_TYPE_OVERALL"] == filter_type1) & (original_data["CREDIT_ACTIVE"] == filter_type2)].groupby(["SK_ID_CURR"]).count().SK_ID_BUREAU
        data_count  = pd.DataFrame()
        data_count  = pd.DataFrame({'SK_ID_CURR':temp_series.index, new_varname:temp_series.values})
        Summerized_data = data.merge(data_count,how="left")
    elif filter_type1 is not None and filter_type2 is None:
        temp_series = original_data[(original_data["CREDIT_TYPE_OVERALL"] == filter_type1)].groupby(["SK_ID_CURR"]).count().SK_ID_BUREAU
        data_count  = pd.DataFrame()
        data_count  = pd.DataFrame({'SK_ID_CURR':temp_series.index, new_varname:temp_series.values})
        Summerized_data = data.merge(data_count,how="left")
    elif filter_type1 is None and filter_type2 is not None:
        temp_series = original_data[(original_data["CREDIT_ACTIVE"] == filter_type2)].groupby(["SK_ID_CURR"]).count().SK_ID_BUREAU
        data_count  = pd.DataFrame()
        data_count  = pd.DataFrame({'SK_ID_CURR':temp_series.index, new_varname:temp_series.values})
        Summerized_data = data.merge(data_count,how="left")
    else :
        temp_series = original_data.groupby(["SK_ID_CURR"]).count().SK_ID_BUREAU
        data_count  = pd.DataFrame()
        data_count  = pd.DataFrame({'SK_ID_CURR':temp_series.index, new_varname:temp_series.values})
        Summerized_data = data.merge(data_count,how="left")    
    return Summerized_data

data_base = trade_count(filter_type1="Unsecured",data=data_base,original_data = bureau,new_varname= 'Unsecured_count')
data_base = trade_count(filter_type1="Unsecured",filter_type2="Active",data=data_base,original_data = bureau,new_varname= 'Unsecured_active_count')
data_base = trade_count(filter_type1="Secured",data=data_base,original_data = bureau,new_varname= 'Secured_count')
data_base = trade_count(filter_type1="Secured",filter_type2="Active",data=data_base,original_data = bureau,new_varname= 'Secured_active_count')
data_base = trade_count(filter_type1="HL",data=data_base,original_data = bureau,new_varname= 'HL_count')
data_base = trade_count(filter_type1="HL",filter_type2="Active",data=data_base,original_data = bureau,new_varname= 'HL_active_count')
data_base = trade_count(data=data_base,original_data = bureau,new_varname= 'Total_count')
data_base = trade_count(filter_type2="Active",data=data_base,original_data = bureau,new_varname= 'Total_active_count')

# %%
def max_time(filter_type1=None,filter_type2 = None,data=None,original_data=None,new_varname = None):
    if (filter_type1 is not None) and (filter_type2 is not None):
        temp_series = original_data[(original_data["CREDIT_TYPE_OVERALL"] == filter_type1) & (original_data["CREDIT_ACTIVE"] == filter_type2)].groupby(['SK_ID_CURR'], sort=False)['DAYS_CREDIT'].max()
        data_count  = pd.DataFrame()
        data_count  = pd.DataFrame({'SK_ID_CURR':temp_series.index, new_varname:temp_series.values})
        Summerized_data = data.merge(data_count,how="left")
    elif filter_type1 is not None and filter_type2 is None:
        temp_series = original_data[(original_data["CREDIT_TYPE_OVERALL"] == filter_type1)].groupby(['SK_ID_CURR'], sort=False)['DAYS_CREDIT'].max()
        data_count  = pd.DataFrame()
        data_count  = pd.DataFrame({'SK_ID_CURR':temp_series.index, new_varname:temp_series.values})
        Summerized_data = data.merge(data_count,how="left")
    elif filter_type1 is None and filter_type2 is not None:
        temp_series = original_data[(original_data["CREDIT_ACTIVE"] == filter_type2)].groupby(['SK_ID_CURR'], sort=False)['DAYS_CREDIT'].max()
        data_count  = pd.DataFrame()
        data_count  = pd.DataFrame({'SK_ID_CURR':temp_series.index, new_varname:temp_series.values})
        Summerized_data = data.merge(data_count,how="left")
    else :
        temp_series = original_data.groupby(['SK_ID_CURR'], sort=False)['DAYS_CREDIT'].max()
        data_count  = pd.DataFrame()
        data_count  = pd.DataFrame({'SK_ID_CURR':temp_series.index, new_varname:temp_series.values})
        Summerized_data = data.merge(data_count,how="left")    
    return Summerized_data

data_base = max_time(filter_type1="Unsecured",data=data_base,original_data = bureau,new_varname= 'Unsecured_max_time')
data_base = max_time(filter_type1="Unsecured",filter_type2="Active",data=data_base,original_data = bureau,new_varname= 'Unsecured_max_active_time')
data_base = max_time(filter_type1="Secured",data=data_base,original_data = bureau,new_varname= 'Secured_max_time')
data_base = max_time(filter_type1="Secured",filter_type2="Active",data=data_base,original_data = bureau,new_varname= 'Secured_max_active_time')
data_base = max_time(filter_type1="HL",data=data_base,original_data = bureau,new_varname= 'HL_max_time')
data_base = max_time(filter_type1="HL",filter_type2="Active",data=data_base,original_data = bureau,new_varname= 'HL_max_active_time')
data_base = max_time(data=data_base,original_data = bureau,new_varname= 'Total_max_time')
data_base = max_time(filter_type2="Active",data=data_base,original_data = bureau,new_varname= 'Total_max_active_time')

# %%
def min_time(filter_type1=None,filter_type2 = None,data=None,original_data=None,new_varname = None):
    if (filter_type1 is not None) and (filter_type2 is not None):
        temp_series = original_data[(original_data["CREDIT_TYPE_OVERALL"] == filter_type1) & (original_data["CREDIT_ACTIVE"] == filter_type2)].groupby(['SK_ID_CURR'], sort=False)['DAYS_CREDIT'].min()
        data_count  = pd.DataFrame()
        data_count  = pd.DataFrame({'SK_ID_CURR':temp_series.index, new_varname:temp_series.values})
        Summerized_data = data.merge(data_count,how="left")
    elif filter_type1 is not None and filter_type2 is None:
        temp_series = original_data[(original_data["CREDIT_TYPE_OVERALL"] == filter_type1)].groupby(['SK_ID_CURR'], sort=False)['DAYS_CREDIT'].min()
        data_count  = pd.DataFrame()
        data_count  = pd.DataFrame({'SK_ID_CURR':temp_series.index, new_varname:temp_series.values})
        Summerized_data = data.merge(data_count,how="left")
    elif filter_type1 is None and filter_type2 is not None:
        temp_series = original_data[(original_data["CREDIT_ACTIVE"] == filter_type2)].groupby(['SK_ID_CURR'], sort=False)['DAYS_CREDIT'].min()
        data_count  = pd.DataFrame()
        data_count  = pd.DataFrame({'SK_ID_CURR':temp_series.index, new_varname:temp_series.values})
        Summerized_data = data.merge(data_count,how="left")
    else :
        temp_series = original_data.groupby(['SK_ID_CURR'], sort=False)['DAYS_CREDIT'].min()
        data_count  = pd.DataFrame()
        data_count  = pd.DataFrame({'SK_ID_CURR':temp_series.index, new_varname:temp_series.values})
        Summerized_data = data.merge(data_count,how="left")    
    return Summerized_data

data_base = min_time(filter_type1="Unsecured",data=data_base,original_data = bureau,new_varname= 'Unsecured_min_time')
data_base = min_time(filter_type1="Unsecured",filter_type2="Active",data=data_base,original_data = bureau,new_varname= 'Unsecured_min_active_time')
data_base = min_time(filter_type1="Secured",data=data_base,original_data = bureau,new_varname= 'Secured_min_time')
data_base = min_time(filter_type1="Secured",filter_type2="Active",data=data_base,original_data = bureau,new_varname= 'Secured_min_active_time')
data_base = min_time(filter_type1="HL",data=data_base,original_data = bureau,new_varname= 'HL_min_time')
data_base = min_time(filter_type1="HL",filter_type2="Active",data=data_base,original_data = bureau,new_varname= 'HL_min_active_time')
data_base = min_time(data=data_base,original_data = bureau,new_varname= 'Total_min_time')
data_base = min_time(filter_type2="Active",data=data_base,original_data = bureau,new_varname= 'Total_min_active_time')

# %%
def avg_time(filter_type1=None,filter_type2 = None,data=None,original_data=None,new_varname = None):
    if (filter_type1 is not None) and (filter_type2 is not None):
        temp_series = original_data[(original_data["CREDIT_TYPE_OVERALL"] == filter_type1) & (original_data["CREDIT_ACTIVE"] == filter_type2)].groupby(['SK_ID_CURR'], sort=False)['DAYS_CREDIT'].mean()
        data_count  = pd.DataFrame()
        data_count  = pd.DataFrame({'SK_ID_CURR':temp_series.index, new_varname:temp_series.values})
        Summerized_data = data.merge(data_count,how="left")
    elif filter_type1 is not None and filter_type2 is None:
        temp_series = original_data[(original_data["CREDIT_TYPE_OVERALL"] == filter_type1)].groupby(['SK_ID_CURR'], sort=False)['DAYS_CREDIT'].mean()
        data_count  = pd.DataFrame()
        data_count  = pd.DataFrame({'SK_ID_CURR':temp_series.index, new_varname:temp_series.values})
        Summerized_data = data.merge(data_count,how="left")
    elif filter_type1 is None and filter_type2 is not None:
        temp_series = original_data[(original_data["CREDIT_ACTIVE"] == filter_type2)].groupby(['SK_ID_CURR'], sort=False)['DAYS_CREDIT'].mean()
        data_count  = pd.DataFrame()
        data_count  = pd.DataFrame({'SK_ID_CURR':temp_series.index, new_varname:temp_series.values})
        Summerized_data = data.merge(data_count,how="left")
    else :
        temp_series = original_data.groupby(['SK_ID_CURR'], sort=False)['DAYS_CREDIT'].mean()
        data_count  = pd.DataFrame()
        data_count  = pd.DataFrame({'SK_ID_CURR':temp_series.index, new_varname:temp_series.values})
        Summerized_data = data.merge(data_count,how="left")    
    return Summerized_data

data_base = avg_time(filter_type1="Unsecured",data=data_base,original_data = bureau,new_varname= 'Unsecured_mean_time')
data_base = avg_time(filter_type1="Unsecured",filter_type2="Active",data=data_base,original_data = bureau,new_varname= 'Unsecured_mean_active_time')
data_base = avg_time(filter_type1="Secured",data=data_base,original_data = bureau,new_varname= 'Secured_mean_time')
data_base = avg_time(filter_type1="Secured",filter_type2="Active",data=data_base,original_data = bureau,new_varname= 'Secured_mean_active_time')
data_base = avg_time(filter_type1="HL",data=data_base,original_data = bureau,new_varname= 'HL_mean_time')
data_base = avg_time(filter_type1="HL",filter_type2="Active",data=data_base,original_data = bureau,new_varname= 'HL_mean_active_time')
data_base = avg_time(data=data_base,original_data = bureau,new_varname= 'Total_mean_time')
data_base = avg_time(filter_type2="Active",data=data_base,original_data = bureau,new_varname= 'Total_mean_active_time')

# %%
def last_month_count(filter_type1=None,filter_type2 = None,month_count=None,data=None,original_data=None,new_varname = None):
    if (filter_type1 is not None) and (filter_type2 is not None):
        temp_series = original_data[(original_data["CREDIT_TYPE_OVERALL"] == filter_type1) & (original_data["CREDIT_ACTIVE"] == filter_type2) & (original_data['DAYS_CREDIT'] <= month_count)].groupby(['SK_ID_CURR'], sort=False).SK_ID_BUREAU.count()
        data_count  = pd.DataFrame()
        data_count  = pd.DataFrame({'SK_ID_CURR':temp_series.index, new_varname:temp_series.values})
        Summerized_data = data.merge(data_count,how="left")
    elif filter_type1 is not None and filter_type2 is None:
        temp_series = original_data[(original_data["CREDIT_TYPE_OVERALL"] == filter_type1) & (original_data['DAYS_CREDIT'] <= month_count)].groupby(['SK_ID_CURR'], sort=False).SK_ID_BUREAU.count()
        data_count  = pd.DataFrame()
        data_count  = pd.DataFrame({'SK_ID_CURR':temp_series.index, new_varname:temp_series.values})
        Summerized_data = data.merge(data_count,how="left")
    elif filter_type1 is None and filter_type2 is not None:
        temp_series = original_data[(original_data["CREDIT_ACTIVE"] == filter_type2) & (original_data['DAYS_CREDIT'] <= month_count) ].groupby(['SK_ID_CURR'], sort=False).SK_ID_BUREAU.count()
        data_count  = pd.DataFrame()
        data_count  = pd.DataFrame({'SK_ID_CURR':temp_series.index, new_varname:temp_series.values})
        Summerized_data = data.merge(data_count,how="left")
    else :
        temp_series = original_data[original_data['DAYS_CREDIT'] <= month_count].groupby(['SK_ID_CURR'], sort=False).SK_ID_BUREAU.count()
        data_count  = pd.DataFrame()
        data_count  = pd.DataFrame({'SK_ID_CURR':temp_series.index, new_varname:temp_series.values})
        Summerized_data = data.merge(data_count,how="left")    
    return Summerized_data

data_base = last_month_count(filter_type1="Unsecured",month_count = 90,data=data_base,original_data = bureau,new_varname= 'Unsecured_last_3m_count')
data_base = last_month_count(filter_type1="Unsecured",filter_type2="Active",month_count = 90,data=data_base,original_data = bureau,new_varname= 'Unsecured_last_3m_active_count')
data_base = last_month_count(filter_type1="Secured",month_count = 90,data=data_base,original_data = bureau,new_varname= 'Secured_last_3m_count')
data_base = last_month_count(filter_type1="Secured",filter_type2="Active",month_count = 90,data=data_base,original_data = bureau,new_varname= 'Secured_last_3m_active_count')
data_base = last_month_count(filter_type1="HL",month_count = 90,data=data_base,original_data = bureau,new_varname= 'HL_last_3m_count')
data_base = last_month_count(filter_type1="HL",filter_type2="Active",month_count = 90,data=data_base,original_data = bureau,new_varname= 'HL_last_3m_active_count')
data_base = last_month_count(month_count = 90,data=data_base,original_data = bureau,new_varname= 'Total_last_3m_count')
data_base = last_month_count(filter_type2="Active",month_count = 90,data=data_base,original_data = bureau,new_varname= 'Total_last_3m_active_count')

data_base = last_month_count(filter_type1="Unsecured",month_count = 180,data=data_base,original_data = bureau,new_varname= 'Unsecured_last_6m_count')
data_base = last_month_count(filter_type1="Unsecured",filter_type2="Active",month_count = 180,data=data_base,original_data = bureau,new_varname= 'Unsecured_last_6m_active_count')
data_base = last_month_count(filter_type1="Secured",month_count = 180,data=data_base,original_data = bureau,new_varname= 'Secured_last_6m_count')
data_base = last_month_count(filter_type1="Secured",filter_type2="Active",month_count = 180,data=data_base,original_data = bureau,new_varname= 'Secured_last_6m_active_count')
data_base = last_month_count(filter_type1="HL",month_count = 180,data=data_base,original_data = bureau,new_varname= 'HL_last_6m_count')
data_base = last_month_count(filter_type1="HL",filter_type2="Active",month_count = 180,data=data_base,original_data = bureau,new_varname= 'HL_last_6m_active_count')
data_base = last_month_count(month_count = 180,data=data_base,original_data = bureau,new_varname= 'Total_last_6m_count')
data_base = last_month_count(filter_type2="Active",month_count = 180,data=data_base,original_data = bureau,new_varname= 'Total_last_6m_active_count')

data_base = last_month_count(filter_type1="Unsecured",month_count = 360,data=data_base,original_data = bureau,new_varname= 'Unsecured_last_12m_count')
data_base = last_month_count(filter_type1="Unsecured",filter_type2="Active",month_count = 360,data=data_base,original_data = bureau,new_varname= 'Unsecured_last_12m_active_count')
data_base = last_month_count(filter_type1="Secured",month_count = 360,data=data_base,original_data = bureau,new_varname= 'Secured_last_12m_count')
data_base = last_month_count(filter_type1="Secured",filter_type2="Active",month_count = 360,data=data_base,original_data = bureau,new_varname= 'Secured_last_12m_active_count')
data_base = last_month_count(filter_type1="HL",month_count = 360,data=data_base,original_data = bureau,new_varname= 'HL_last_12m_count')
data_base = last_month_count(filter_type1="HL",filter_type2="Active",month_count = 360,data=data_base,original_data = bureau,new_varname= 'HL_last_12m_active_count')
data_base = last_month_count(month_count = 360,data=data_base,original_data = bureau,new_varname= 'Total_last_12m_count')
data_base = last_month_count(filter_type2="Active",month_count = 360,data=data_base,original_data = bureau,new_varname= 'Total_last_12m_active_count')

# %%
def delq_count(filter_type1=None,filter_type2 = None,delq=None,data=None,original_data=None,new_varname = None):
    if (filter_type1 is not None) and (filter_type2 is not None):
        temp_series = original_data[(original_data["CREDIT_TYPE_OVERALL"] == filter_type1) & (original_data["CREDIT_ACTIVE"] == filter_type2) & (original_data['CREDIT_DAY_OVERDUE'] >= delq)].groupby(['SK_ID_CURR'], sort=False).SK_ID_BUREAU.count()
        data_count  = pd.DataFrame()
        data_count  = pd.DataFrame({'SK_ID_CURR':temp_series.index, new_varname:temp_series.values})
        Summerized_data = data.merge(data_count,how="left")
    elif filter_type1 is not None and filter_type2 is None:
        temp_series = original_data[(original_data["CREDIT_TYPE_OVERALL"] == filter_type1) & (original_data['CREDIT_DAY_OVERDUE'] >= delq)].groupby(['SK_ID_CURR'], sort=False).SK_ID_BUREAU.count()
        data_count  = pd.DataFrame()
        data_count  = pd.DataFrame({'SK_ID_CURR':temp_series.index, new_varname:temp_series.values})
        Summerized_data = data.merge(data_count,how="left")
    elif filter_type1 is None and filter_type2 is not None:
        temp_series = original_data[(original_data["CREDIT_ACTIVE"] == filter_type2) & (original_data['CREDIT_DAY_OVERDUE'] >= delq) ].groupby(['SK_ID_CURR'], sort=False).SK_ID_BUREAU.count()
        data_count  = pd.DataFrame()
        data_count  = pd.DataFrame({'SK_ID_CURR':temp_series.index, new_varname:temp_series.values})
        Summerized_data = data.merge(data_count,how="left")
    else :
        temp_series = original_data[original_data['CREDIT_DAY_OVERDUE'] >= delq].groupby(['SK_ID_CURR'], sort=False).SK_ID_BUREAU.count()
        data_count  = pd.DataFrame()
        data_count  = pd.DataFrame({'SK_ID_CURR':temp_series.index, new_varname:temp_series.values})
        Summerized_data = data.merge(data_count,how="left")    
    return Summerized_data

data_base = delq_count(filter_type1="Unsecured",delq = 1,data=data_base,original_data = bureau,new_varname= 'Unsecured_X+_count')
data_base = delq_count(filter_type1="Unsecured",filter_type2="Active",delq = 1,data=data_base,original_data = bureau,new_varname= 'Unsecured_X+_active_count')
data_base = delq_count(filter_type1="Secured",delq = 1,data=data_base,original_data = bureau,new_varname= 'Secured_X+_count')
data_base = delq_count(filter_type1="Secured",filter_type2="Active",delq = 1,data=data_base,original_data = bureau,new_varname= 'Secured_X+_active_count')
data_base = delq_count(filter_type1="HL",delq = 1,data=data_base,original_data = bureau,new_varname= 'HL_X+_count')
data_base = delq_count(filter_type1="HL",filter_type2="Active",delq = 1,data=data_base,original_data = bureau,new_varname= 'HL_X+_active_count')
data_base = delq_count(delq = 1,data=data_base,original_data = bureau,new_varname= 'Total_X+_count')
data_base = delq_count(filter_type2="Active",delq = 1,data=data_base,original_data = bureau,new_varname= 'Total_X+_active_count')

data_base = delq_count(filter_type1="Unsecured",delq = 30,data=data_base,original_data = bureau,new_varname= 'Unsecured_30+_count')
data_base = delq_count(filter_type1="Unsecured",filter_type2="Active",delq = 30,data=data_base,original_data = bureau,new_varname= 'Unsecured_30+_active_count')
data_base = delq_count(filter_type1="Secured",delq = 30,data=data_base,original_data = bureau,new_varname= 'Secured_30+_count')
data_base = delq_count(filter_type1="Secured",filter_type2="Active",delq = 30,data=data_base,original_data = bureau,new_varname= 'Secured_30+_active_count')
data_base = delq_count(filter_type1="HL",delq = 30,data=data_base,original_data = bureau,new_varname= 'HL_30+_count')
data_base = delq_count(filter_type1="HL",filter_type2="Active",delq = 30,data=data_base,original_data = bureau,new_varname= 'HL_30+_count')
data_base = delq_count(delq = 30,data=data_base,original_data = bureau,new_varname= 'Total_30+_count')
data_base = delq_count(filter_type2="Active",delq = 30,data=data_base,original_data = bureau,new_varname= 'Total_30+_count')

data_base = delq_count(filter_type1="Unsecured",delq = 60,data=data_base,original_data = bureau,new_varname= 'Unsecured_60+_count')
data_base = delq_count(filter_type1="Unsecured",filter_type2="Active",delq = 60,data=data_base,original_data = bureau,new_varname= 'Unsecured_60+_active_count')
data_base = delq_count(filter_type1="Secured",delq = 60,data=data_base,original_data = bureau,new_varname= 'Secured_60+_count')
data_base = delq_count(filter_type1="Secured",filter_type2="Active",delq = 60,data=data_base,original_data = bureau,new_varname= 'Secured_60+_active_count')
data_base = delq_count(filter_type1="HL",delq = 60,data=data_base,original_data = bureau,new_varname= 'HL_60+_count')
data_base = delq_count(filter_type1="HL",filter_type2="Active",delq = 60,data=data_base,original_data = bureau,new_varname= 'HL_60+_active_count')
data_base = delq_count(delq = 60,data=data_base,original_data = bureau,new_varname= 'Total_60+_count')
data_base = delq_count(filter_type2="Active",delq = 60,data=data_base,original_data = bureau,new_varname= 'Total_60+_active_count')

data_base = delq_count(filter_type1="Unsecured",delq = 90,data=data_base,original_data = bureau,new_varname= 'Unsecured_90+_count')
data_base = delq_count(filter_type1="Unsecured",filter_type2="Active",delq = 90,data=data_base,original_data = bureau,new_varname= 'Unsecured_90+_active_count')
data_base = delq_count(filter_type1="Secured",delq = 90,data=data_base,original_data = bureau,new_varname= 'Secured_90+_count')
data_base = delq_count(filter_type1="Secured",filter_type2="Active",delq = 90,data=data_base,original_data = bureau,new_varname= 'Secured_90+_active_count')
data_base = delq_count(filter_type1="HL",delq = 90,data=data_base,original_data = bureau,new_varname= 'HL_90+_count')
data_base = delq_count(filter_type1="HL",filter_type2="Active",delq = 90,data=data_base,original_data = bureau,new_varname= 'HL_90+_active_count')
data_base = delq_count(delq = 90,data=data_base,original_data = bureau,new_varname= 'Total_90+_count')
data_base = delq_count(filter_type2="Active",delq = 90,data=data_base,original_data = bureau,new_varname= 'Total_90+_active_count')

# %%
def delq_min(filter_type1=None,filter_type2 = None,delq=None,data=None,original_data=None,new_varname = None):
    if (filter_type1 is not None) and (filter_type2 is not None):
        temp_series = original_data[(original_data["CREDIT_TYPE_OVERALL"] == filter_type1) & (original_data["CREDIT_ACTIVE"] == filter_type2) & (original_data['CREDIT_DAY_OVERDUE'] >= delq)].groupby(['SK_ID_CURR'], sort=False)['DAYS_CREDIT'].min()
        data_count  = pd.DataFrame()
        data_count  = pd.DataFrame({'SK_ID_CURR':temp_series.index, new_varname:temp_series.values})
        Summerized_data = data.merge(data_count,how="left")
    elif filter_type1 is not None and filter_type2 is None:
        temp_series = original_data[(original_data["CREDIT_TYPE_OVERALL"] == filter_type1) & (original_data['CREDIT_DAY_OVERDUE'] >= delq)].groupby(['SK_ID_CURR'], sort=False)['DAYS_CREDIT'].min()
        data_count  = pd.DataFrame()
        data_count  = pd.DataFrame({'SK_ID_CURR':temp_series.index, new_varname:temp_series.values})
        Summerized_data = data.merge(data_count,how="left")
    elif filter_type1 is None and filter_type2 is not None:
        temp_series = original_data[(original_data["CREDIT_ACTIVE"] == filter_type2) & (original_data['CREDIT_DAY_OVERDUE'] >= delq) ].groupby(['SK_ID_CURR'], sort=False)['DAYS_CREDIT'].min()
        data_count  = pd.DataFrame()
        data_count  = pd.DataFrame({'SK_ID_CURR':temp_series.index, new_varname:temp_series.values})
        Summerized_data = data.merge(data_count,how="left")
    else :
        temp_series = original_data[original_data['CREDIT_DAY_OVERDUE'] >= delq].groupby(['SK_ID_CURR'], sort=False)['DAYS_CREDIT'].min()
        data_count  = pd.DataFrame()
        data_count  = pd.DataFrame({'SK_ID_CURR':temp_series.index, new_varname:temp_series.values})
        Summerized_data = data.merge(data_count,how="left")    
    return Summerized_data

data_base = delq_min(filter_type1="Unsecured",delq = 1,data=data_base,original_data = bureau,new_varname= 'Unsecured_delq_min')
data_base = delq_min(filter_type1="Unsecured",filter_type2="Active",delq = 1,data=data_base,original_data = bureau,new_varname= 'Unsecured_delq_active_min')
data_base = delq_min(filter_type1="Secured",delq = 1,data=data_base,original_data = bureau,new_varname= 'Secured_delq_min')
data_base = delq_min(filter_type1="Secured",filter_type2="Active",delq = 1,data=data_base,original_data = bureau,new_varname= 'Secured_delq_active_min')
data_base = delq_min(filter_type1="HL",delq = 1,data=data_base,original_data = bureau,new_varname= 'HL_delq_min')
data_base = delq_min(filter_type1="HL",filter_type2="Active",delq = 1,data=data_base,original_data = bureau,new_varname= 'HL_delq_active_min')
data_base = delq_min(delq = 1,data=data_base,original_data = bureau,new_varname= 'Total_delq_min')
data_base = delq_min(filter_type2="Active",delq = 1,data=data_base,original_data = bureau,new_varname= 'Total_delq_active_min')

# %%
def delq_max(filter_type1=None,filter_type2 = None,delq=None,data=None,original_data=None,new_varname = None):
    if (filter_type1 is not None) and (filter_type2 is not None):
        temp_series = original_data[(original_data["CREDIT_TYPE_OVERALL"] == filter_type1) & (original_data["CREDIT_ACTIVE"] == filter_type2) & (original_data['CREDIT_DAY_OVERDUE'] >= delq)].groupby(['SK_ID_CURR'], sort=False)['DAYS_CREDIT'].max()
        data_count  = pd.DataFrame()
        data_count  = pd.DataFrame({'SK_ID_CURR':temp_series.index, new_varname:temp_series.values})
        Summerized_data = data.merge(data_count,how="left")
    elif filter_type1 is not None and filter_type2 is None:
        temp_series = original_data[(original_data["CREDIT_TYPE_OVERALL"] == filter_type1) & (original_data['CREDIT_DAY_OVERDUE'] >= delq)].groupby(['SK_ID_CURR'], sort=False)['DAYS_CREDIT'].max()
        data_count  = pd.DataFrame()
        data_count  = pd.DataFrame({'SK_ID_CURR':temp_series.index, new_varname:temp_series.values})
        Summerized_data = data.merge(data_count,how="left")
    elif filter_type1 is None and filter_type2 is not None:
        temp_series = original_data[(original_data["CREDIT_ACTIVE"] == filter_type2) & (original_data['CREDIT_DAY_OVERDUE'] >= delq) ].groupby(['SK_ID_CURR'], sort=False)['DAYS_CREDIT'].max()
        data_count  = pd.DataFrame()
        data_count  = pd.DataFrame({'SK_ID_CURR':temp_series.index, new_varname:temp_series.values})
        Summerized_data = data.merge(data_count,how="left")
    else :
        temp_series = original_data[original_data['CREDIT_DAY_OVERDUE'] >= delq].groupby(['SK_ID_CURR'], sort=False)['DAYS_CREDIT'].max()
        data_count  = pd.DataFrame()
        data_count  = pd.DataFrame({'SK_ID_CURR':temp_series.index, new_varname:temp_series.values})
        Summerized_data = data.merge(data_count,how="left")    
    return Summerized_data

data_base = delq_max(filter_type1="Unsecured",delq = 1,data=data_base,original_data = bureau,new_varname= 'Unsecured_delq_max')
data_base = delq_max(filter_type1="Unsecured",filter_type2="Active",delq = 1,data=data_base,original_data = bureau,new_varname= 'Unsecured_delq_active_max')
data_base = delq_max(filter_type1="Secured",delq = 1,data=data_base,original_data = bureau,new_varname= 'Secured_delq_max')
data_base = delq_max(filter_type1="Secured",filter_type2="Active",delq = 1,data=data_base,original_data = bureau,new_varname= 'Secured_delq_active_max')
data_base = delq_max(filter_type1="HL",delq = 1,data=data_base,original_data = bureau,new_varname= 'HL_delq_max')
data_base = delq_max(filter_type1="HL",filter_type2="Active",delq = 1,data=data_base,original_data = bureau,new_varname= 'HL_delq_active_max')
data_base = delq_max(delq = 1,data=data_base,original_data = bureau,new_varname= 'Total_delq_max')
data_base = delq_max(filter_type2="Active",delq = 1,data=data_base,original_data = bureau,new_varname= 'Total_delq_active_max')

# %%
def delq_avg(filter_type1=None,filter_type2 = None,delq=None,data=None,original_data=None,new_varname = None):
    if (filter_type1 is not None) and (filter_type2 is not None):
        temp_series = original_data[(original_data["CREDIT_TYPE_OVERALL"] == filter_type1) & (original_data["CREDIT_ACTIVE"] == filter_type2) & (original_data['CREDIT_DAY_OVERDUE'] >= delq)].groupby(['SK_ID_CURR'], sort=False)['DAYS_CREDIT'].mean()
        data_count  = pd.DataFrame()
        data_count  = pd.DataFrame({'SK_ID_CURR':temp_series.index, new_varname:temp_series.values})
        Summerized_data = data.merge(data_count,how="left")
    elif filter_type1 is not None and filter_type2 is None:
        temp_series = original_data[(original_data["CREDIT_TYPE_OVERALL"] == filter_type1) & (original_data['CREDIT_DAY_OVERDUE'] >= delq)].groupby(['SK_ID_CURR'], sort=False)['DAYS_CREDIT'].mean()
        data_count  = pd.DataFrame()
        data_count  = pd.DataFrame({'SK_ID_CURR':temp_series.index, new_varname:temp_series.values})
        Summerized_data = data.merge(data_count,how="left")
    elif filter_type1 is None and filter_type2 is not None:
        temp_series = original_data[(original_data["CREDIT_ACTIVE"] == filter_type2) & (original_data['CREDIT_DAY_OVERDUE'] >= delq) ].groupby(['SK_ID_CURR'], sort=False)['DAYS_CREDIT'].mean()
        data_count  = pd.DataFrame()
        data_count  = pd.DataFrame({'SK_ID_CURR':temp_series.index, new_varname:temp_series.values})
        Summerized_data = data.merge(data_count,how="left")
    else :
        temp_series = original_data[original_data['CREDIT_DAY_OVERDUE'] >= delq].groupby(['SK_ID_CURR'], sort=False)['DAYS_CREDIT'].mean()
        data_count  = pd.DataFrame()
        data_count  = pd.DataFrame({'SK_ID_CURR':temp_series.index, new_varname:temp_series.values})
        Summerized_data = data.merge(data_count,how="left")    
    return Summerized_data

data_base = delq_avg(filter_type1="Unsecured",delq = 1,data=data_base,original_data = bureau,new_varname= 'Unsecured_delq_avg')
data_base = delq_avg(filter_type1="Unsecured",filter_type2="Active",delq = 1,data=data_base,original_data = bureau,new_varname= 'Unsecured_delq_active_avg')
data_base = delq_avg(filter_type1="Secured",delq = 1,data=data_base,original_data = bureau,new_varname= 'Secured_delq_avg')
data_base = delq_avg(filter_type1="Secured",filter_type2="Active",delq = 1,data=data_base,original_data = bureau,new_varname= 'Secured_delq_active_avg')
data_base = delq_avg(filter_type1="HL",delq = 1,data=data_base,original_data = bureau,new_varname= 'HL_delq_avg')
data_base = delq_avg(filter_type1="HL",filter_type2="Active",delq = 1,data=data_base,original_data = bureau,new_varname= 'HL_delq_active_avg')
data_base = delq_avg(delq = 1,data=data_base,original_data = bureau,new_varname= 'Total_delq_avg')
data_base = delq_avg(filter_type2="Active",delq = 1,data=data_base,original_data = bureau,new_varname= 'Total_delq_active_avg')

# %%
#col = list(data_base.columns.values)
#col.remove('SK_ID_CURR')

# %%
#buro_bal_id = buro_bal_id.drop(['MONTHS_BALANCE','CREDIT_TYPE_OVERALL','STATUS','AMT_CREDIT_SUM','AMT_CREDIT_MAX_OVERDUE',
#                               'AMT_CREDIT_SUM_DEBT','AMT_CREDIT_SUM_OVERDUE','CREDIT_TYPE','STATUS_FLOAT'],axis=1)

# %%
data_base.to_pickle("bureau_1.p")
